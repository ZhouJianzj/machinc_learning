# %%
import pandas as pd
import matplotlib.pyplot as plt

from pylab import mpl

# %%
# 解决中文乱码问题的：https://www.nhooo.com/note/qagwwg.html
#mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 指定默认字体：解决plot不能显示中文问题
mpl.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

# %%
data = pd.read_csv("./assert/air_quality_no2.csv")
data
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
# 新的列
data["new Column"] = data["station_antwerp"] / 2
data["new Column"].plot()
# data["new Column"]
# Out:
# <Axes: >

# %%
# 重新命名column
data = data.rename(columns={
    "station_antwerp": "安特卫普站",
    "station_paris": "巴黎站",
    "station_london": "伦敦车站"
})
data
# Out:
#                  datetime  安特卫普站   巴黎站  伦敦车站  new Column
# 0     2019-05-07 02:00:00    NaN   NaN  23.0         NaN
# 1     2019-05-07 03:00:00   50.5  25.0  19.0       25.25
# 2     2019-05-07 04:00:00   45.0  27.7  19.0       22.50
# 3     2019-05-07 05:00:00    NaN  50.4  16.0         NaN
# 4     2019-05-07 06:00:00    NaN  61.9   NaN         NaN
# ...                   ...    ...   ...   ...         ...
# 1030  2019-06-20 22:00:00    NaN  21.4   NaN         NaN
# 1031  2019-06-20 23:00:00    NaN  24.9   NaN         NaN
# 1032  2019-06-21 00:00:00    NaN  26.5   NaN         NaN
# 1033  2019-06-21 01:00:00    NaN  21.8   NaN         NaN
# 1034  2019-06-21 02:00:00    NaN  20.0   NaN         NaN
#
# [1035 rows x 5 columns]

# %%
data.plot()
# Out:
# <Axes: >
